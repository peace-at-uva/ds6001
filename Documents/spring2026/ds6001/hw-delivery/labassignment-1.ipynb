# %% [markdown]
# # Lab Assignment 1 for DS6001
# #### Peace Gwam
# #### January 19, 2026
#
# ## Problem 0
#
# Part a: Virtual environments isolates the Pyton version and packages installed on that version. It allows for reproducible code and keeps everything organized.
#
# Part b: A global environment doesn't isolate anything. A virtual environment isolates the Python version and packages installed on that version. A container has the capabilities of a virtual environment plus the ability to connect to database systems like SQL. A virtual machine is an external system like AWS that is accessed through cloud computing.
#
# Part c: Completed!
#
# ## Problem 1
#
# Part a: SyntaxError
#
# Part b: IndentationError
#
# Part c: MemoryError
#
# Pard d: ZeroDivisionError
#
# Part e: NameError
#
# Part f: OSError
#
# Part g: TypeError
#
# Part h: RuntimeError
#
# ## Problem 2

# %%
"""Part a"""
engine = "c"

# %%
"""Part b"""
mytrips = {'Portland': 'So many bicycles',
'Nashville': 'Lost in Opryland Mall again',
'Richmond': 'Got tattoo and became a hipster',
'San Diego': 'Chased off beach by sea lion'}
list(mytrips.keys())
# Out:
# ['Portland', 'Nashville', 'Richmond', 'San Diego']

# %%
"""Part c"""
import plotly.express as px

df = px.data.tips()

fig = px.scatter(df, x="total_bill", y="tip", marginal_x="box")
fig.show()

# %% [markdown]
# ## Problem 3
#
# Part a: https://stackoverflow.com/questions/34617958/increment-subsequent-dictionary-keys-when-inserting-a-new-key In this case, the question asker used dictionary keys in a...unique way. The post was downvoted, and the top responses were: "Doesn't seem very natural." and "Why are you not just using a list!?"
#
# Part b: https://stackoverflow.com/questions/79871378/how-do-i-detect-if-any-python-file-py-is-open-in-python
# In this case, the question was downvoted and closed with very little explanation because they did not explain what they tried beforehand.
#
# ## Problem 4
#
# Part a: I can't find it.
#
# Part b: Why is it that in my function when it takes in a string that is not part of the parameters, it still prints as if it is?
#
# Part c: def func(name):
#     if name == "Bob"
#         print (name + "")
#         else:
#             print (name + "NOT")
#
#
# ## Problem 5

# %%
"""part a"""
def collatz_step(n):
    """
    Apply one step of the Collatz algorithm to a positive integer n.
    """
    if n <= 0:
        raise ValueError("Input must be a positive integer")
    
    if n % 2 == 0:
        return n // 2
    else:
        return 3 * n + 1

# %%
"""part b"""
def collatz_step(n):
    """
    Apply one step of the Collatz algorithm to a positive integer n.
    """
    if n <= 0:
        if not isinstance(n, int):
            raise TypeError("Input must be an integer")
        if n < 0:
            raise ValueError("Input must be a positive integer")
        raise ValueError("Input must be a positive integer")
    
    if n % 2 == 0:
        return n // 2
    else:
        return 3 * n + 1

# %%
"""part c"""
def collatz_to_one(start):
    n = start
    while n != 1:
        n = collatz_to_one(n)
        print(n)
